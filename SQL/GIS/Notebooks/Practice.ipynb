-- %%
-- select max(o.VersionID) as MaxVersion, o.OwnerID
-- from Owners o
-- GROUP by o.OwnerID
-- select max(p.VersionID) as MaxVersion, p.OwnerID
-- from PropertyOwners p
-- GROUP BY p.OwnerID
-- select *
-- from PropertyOwners po
-- where po.YearID = '2020'
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.014
-- ...
